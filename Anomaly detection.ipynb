# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import csv

# %%
df = pd.read_excel('data.xlsx')

# %%
df
# Out:
#                       time Cyclone_Inlet_Gas_Temp Cyclone_Material_Temp  \
# 0      2017-01-01 00:00:00                 867.63                910.42
# 1      2017-01-01 00:05:00                 879.23                918.14
# 2      2017-01-01 00:10:00                 875.67                924.18
# 3      2017-01-01 00:15:00                 875.28                923.15
# 4      2017-01-01 00:20:00                 891.66                934.26
# ...                    ...                    ...                   ...
# 377714 2020-08-07 11:55:00                 899.42                919.79
# 377715 2020-08-07 12:00:00                  879.9                895.02
# 377716 2020-08-07 12:05:00                  887.2                 895.7
# 377717 2020-08-07 12:10:00                  908.5                916.33
# 377718 2020-08-07 12:15:00                 880.86                905.31
#
#        Cyclone_Outlet_Gas_draft Cyclone_cone_draft Cyclone_Gas_Outlet_Temp  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 377719 entries, 0 to 377718
# Data columns (total 7 columns):
# time                        377719 non-null datetime64[ns]
# Cyclone_Inlet_Gas_Temp      377719 non-null object
# Cyclone_Material_Temp       377719 non-null object
# Cyclone_Outlet_Gas_draft    377719 non-null object
# Cyclone_cone_draft          377719 non-null object
# Cyclone_Gas_Outlet_Temp     377719 non-null object
# Cyclone_Inlet_Draft         377719 non-null object
# dtypes: datetime64[ns](1), object(6)
# memory usage: 20.2+ MB

# %%
df.describe()
# Out:
#                        time Cyclone_Inlet_Gas_Temp  Cyclone_Material_Temp  \
# count                377719                 377719               377719.0
# unique               377719                  39736                39662.0
# top     2019-08-17 15:40:00            Not Connect                    0.0
# freq                      1                    723                14226.0
# first   2017-01-01 00:00:00                    NaN                    NaN
# last    2020-08-07 12:15:00                    NaN                    NaN
#
#        Cyclone_Outlet_Gas_draft Cyclone_cone_draft  Cyclone_Gas_Outlet_Temp  \
# count                    377719             377719                377719.00
# unique                    27669              26487                 48044.00
# top                 Not Connect        Not Connect                    28.88
# freq                        723                723                  2036.00
# ...

# %%
x = df[~df.applymap(np.isreal).all(1)]

# %%
x
# Out:
#                       time Cyclone_Inlet_Gas_Temp Cyclone_Material_Temp  \
# 2471   2017-01-09 13:55:00            I/O Timeout           I/O Timeout
# 2472   2017-01-09 14:00:00            I/O Timeout           I/O Timeout
# 2473   2017-01-09 14:05:00            I/O Timeout           I/O Timeout
# 2474   2017-01-09 14:10:00            I/O Timeout           I/O Timeout
# 2475   2017-01-09 14:15:00            I/O Timeout           I/O Timeout
# ...                    ...                    ...                   ...
# 375585 2020-07-31 02:30:00                 886.18             Unit Down
# 375850 2020-08-01 00:35:00                 877.45             Unit Down
# 376010 2020-08-01 13:55:00                 886.24             Unit Down
# 376885 2020-08-04 14:50:00                 886.11             Unit Down
# 376956 2020-08-04 20:45:00                 881.34             Unit Down
#
#        Cyclone_Outlet_Gas_draft Cyclone_cone_draft Cyclone_Gas_Outlet_Temp  \
# ...

# %%
x.to_excel('anomaly.xlsx')

# %%
x['time']
# Out:
# 2471     2017-01-09 13:55:00
# 2472     2017-01-09 14:00:00
# 2473     2017-01-09 14:05:00
# 2474     2017-01-09 14:10:00
# 2475     2017-01-09 14:15:00
#                  ...
# 375585   2020-07-31 02:30:00
# 375850   2020-08-01 00:35:00
# 376010   2020-08-01 13:55:00
# 376885   2020-08-04 14:50:00
# 376956   2020-08-04 20:45:00
# Name: time, Length: 1595, dtype: datetime64[ns]
